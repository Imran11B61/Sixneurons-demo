# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Read & convert bengali digit to gray scale

# %%
img = cv2.imread('Documents\\one.png')
imgGray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
cv2.imshow("Grayimage", imgGray)
cv2.waitKey(5000)
# Out:
# -1

# %%
imgGray.shape
# Out:
# (900, 900)

# %% [markdown]
# ### Display the digit (Original & Grayscale)

# %%
plt.imshow(img)

# %%
plt.imshow(imgGray)

# %% [markdown]
# ### Convert digit into matrix

# %%
print(imgGray)
# Out:
# [[255 255 255 ... 230 230 230]
#  [255 255 255 ... 230 230 230]
#  [255 255 255 ... 230 230 230]
#  ...
#  [230 230 230 ... 255 255 255]
#  [230 230 230 ... 255 255 255]
#  [230 230 230 ... 255 255 255]]

# %%
resized_imgGray = cv2.resize(imgGray,(20,18))
reverse_img = 255 - resized_imgGray
print(reverse_img)
# Out:
# [[  0  25   0  25   0  25   0  25   0  25   0  25   0  25   0  25   0  25
#     0  25]
#  [ 12  12  12  12  12  12  12  12  12  12  12  12  12  12  12  12  12  12
#    12  12]
#  [ 25   0  25   0  25   0 124 255 255   0  25   0  25   0  25   0  25   0
#    25   0]
#  [  0  25   0  25   0  25 255 255 255  25   0  25   0  25   0  25   0  25
#     0  25]
#  [ 12  12  12  12  12  12  12 255 255 255  12  12  12  12  12  12  12  12
#    12  12]
#  [ 25   0  25   0  25   0  25   0 255 255 255   0  25   0  25   0  25   0
#    25   0]
#  [  0  25   0  25   0  25   0  25   0 255 255 255   0  25   0  25   0  25
#     0  25]
#  [ 12  12  12  12  12  12  12  12  12  12 255 255 255  12  12  12  12  12
#    12  12]
#  [ 25   0  25   0  25   0  25   0  25   0  25 255 255   0  25   0  25   0
#    25   0]
#  [  0  25   0  25   0  25   0  25   0  25   0  25 255 255   0  25   0  25
#     0  25]
#  [ 12  12  12  12  12  12  12  12  12  12  12  12  12 255  12  12  12  12
#    12  12]
# ...
